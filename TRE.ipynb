# %% [markdown]
# # TRE

# %% [markdown]
# # 1. Landmark Points

# %%
import SimpleITK as sitk
#print(sitk.Version())
import numpy as np

# %%
 reference_fixed_point_list_T00 =  [
 [346.29,	295.85 ,	192.5],	
 [229.89,	287.12 ,	217.5],	
 [222.13,	291    ,	102.5],	
 [221.16,	244.44 ,	  220],	
 [202.73,	259.96 ,    127.5],	
 [224,   	296.82 ,	   95],	
 [182.36,	231.83 ,	147.5],	
 [356.96,	243.47 ,	102.5],	
 [155.2	,   277.42 ,    232.5],	
 [233.77,	266.75 ,	  235],	
 [368.6	,   273.54 ,	  210],	
 [216.31,	265.78 ,	237.5],	
 [247.35,	255.11 ,	   80],	
 [196.91,	239.59 ,	  185],	
 [342.41,	291.   ,    112.5],	
 [240.56,	252.2  ,     57.5],	
 [167.81,	270.63 ,	222.5],	
 [322,	    263.84 ,	  185],	
 [199.82,	287.12 ,	  235],	
 [377.33,	265.78 ,	  135],	
 [226.98,	291.   ,     77.5],	
 [388	,   232.8 ,       205],	
 [204.67,	267.72 ,	  225],	
 [340.47,	306.52 ,	  145],	
 [211.46,	291	   ,      170],	
 [351.14,	293.91 ,	162.5],	
 [338.53,	300.7  ,    132.5],	
 [214.37,	289    ,	   90],	
 [183.33,	183.33 ,	152.5],	
 [227.95,	282.27 ,	247.5],	
 [204.67,	263.84 ,	  125],	
 [172.66,	235.71 ,	  195],	
 [229.89,	287.12 ,	  150],	
 [158.11,	239.59 ,	  190],	
 [344.35,	290    ,	232.5],	
 [237.65,	249.29 ,	 92.5],	
 [212.43,	265.78 ,	 62.5],	
 [183.33,	293.91 ,	  235],	
 [208.55,	300.7  ,    172.5],	
 [200.79,	294.88 ,	  185],	
 [205.64,	263.84 ,	  175],	
 [327.86,	222.13 ,	   80],	
 [323,	    250.26 ,	 67.5],	
 [167.81,	254.14 ,	132.5],	
 [377.33,	260.93 ,	152.5],	
 [180.42,	211.46 ,	167.5],	
 [374.42,	270.63 ,	192.5],	
 [211.46,	224    ,	167.5],	
 [236.68,	293.91 ,	147.5],	
 [211.46,	288    ,	 82.5],	
 [367.63,	214.37 ,	157.5],	
 [219.22,	281.3  ,      115],	
 [188.18,	255.11 ,	142.5],	
 [362.78,	276.45 ,	  165],	
 [178.48,	257    ,	  170],	
 [325.92,	242.5  ,       85],	
 [223.1	,   301.67 ,	152.5],	
 [388	,   229.89 ,	212.5],	
 [179.45,	265.78 ,	172.5],	
 [253.17,	276.45 ,	  125],	
 [348.23,	264.81 ,	132.5],	
 [199.82,	234.74 ,	  200],	
 [241.53,	253.17 ,	  52.5],	
 [155.2	,   211.46 ,	 192.5],	
 [186.24,	213.4  ,       110],	
 [195.94,	283.24 ,	   225],	
 [196.91,	237.65 ,	 147.5],	
 [391.88,	241.53 ,	 177.5],	
 [322   ,	264.81 ,	 182.5],	
 [193   ,	289    ,	   125],	
 [329.8	,   273.54 ,	  77.5],	
 [339.5	,   288    ,	 157.5],	
 [338.53,	292.94 ,	   200],	
 [329.8	,   225    ,	 102.5],	
 [173.63,	288    ,	 197.5],	
 [226.98,	299.73 ,	 107.5],	
 [182.36,	289    ,	 157.5],	
 [157.14,	224    ,	   195],	
 [201.76,	285.18 ,	  97.5],	
 [212.43,	285.18 ,	   175],	
 [315.25,	286.15 ,	   130],	
 [217.28,	244.44 ,	 107.5],	
 [210.49,	245.41 ,	    75],	
 [195.94,	201.76 ,	 132.5],	
 [205.64,	297.79 ,	   165],	
 [323.98,	269.66 ,	   175],	
 [235.71,	292.94 ,	    95],	
 [222.13,	257    ,	  57.5],	
 [188.18,	222.13 ,	   120],	
 [227.95,	252.2  ,        50],	
 [315.25,	284.21 ,	   135],	
 [377.33,	233.77 ,	   150],	
 [370.54,	284.21 ,	 162.5],	
 [225   ,	264.81 ,	  67.5],	
 [327.86,	237.65 ,	  82.5],	
 [323.98,	273.54 ,	   155],	
 [200.79,	298.76 ,	   230],	
 [383.15,	251.23 ,	 197.5],	
 [207.58,	228.92 ,	   100],	
 [384.12,	246.38 ,	 247.5],	
 [190.12,	300.7  ,     187.5],	
 [320.1	,   253.17 ,	    65],	
 [326.89,	271.6  ,      87.5],	
 [210.49,	280.33 ,	   235],	
 [335.62,	291.97 ,	 212.5],	
 [347.26,	301.67 ,	   175],	
 [339.5	,   281.3  ,    195   ],	
 [328.83,	264.81 , 	207.5 ],	
 [254.14,	274.51 , 	87.5  ],	
 [364.72,	287.12 , 	230   ],	
 [161.99,	249.29 , 	185   ],	
 [335.62,	245.41 , 	62.5  ],	
 [332.71,	274.51 , 	220   ],	
 [377.33,	233.77 , 	147.5 ],	
 [327.86,	272.57 , 	195   ],	
 [366.66,	268.69 , 	115   ],	
 [247.35,	266.75 , 	112.5 ],	
 [220.19,	301.67 , 	205   ],	
 [328.83,	297.79 , 	127.5 ],	
 [257   ,	265.78 , 	90    ],	
 [179.45,	226    , 	165   ],	
 [237.65,	287.12 , 	182.5 ],	
 [182.36,	216.31 , 	165   ],	
 [182.36,	233.77 , 	187.5 ],	
 [332.71,	273.54 , 	55    ],	
 [342.41,	279.36 , 	232.5 ],	
 [234.74,	259.96 , 	215   ],	
 [336.59,	284.21 , 	227.5 ],	
 [183.33,	297.79 , 	215   ],	
 [178.48,	269.66 , 	135   ],	
 [182.36,	282.27 , 	217.5 ],	
 [343.38,	291    ,    150   ],	
 [225   ,	263.84 ,	70    ],	
 [329.8 ,   263.84 ,	110   ],	
 [189.15,	263.84 ,	182.5 ],	
 [192   ,	296.82 ,	165   ],	
 [205.64,	278.39 ,	230   ],	
 [202.73,	301.67 ,	112.5 ],	
 [248.32,	264.81 ,	137.5 ],	
 [338.53,	202.73 ,	107.5 ],	
 [178.48,	240.56 ,	192.5 ],	
 [167.81,	282.27 ,	195   ],	
 [204.67,	288    ,	155   ],	
 [323.98,	282.27 ,	150   ],	
 [334.65,	288    ,	100     ],	
 [242.5	,   258.99 ,	50      ],	
 [365.69,	215.34 ,	150     ],	
 [203.7	,   289    ,	212.5   ],	 
 [194.97,	232.8  ,	137.5   ],	 
 [208.55,	296.82 ,	150     ],	
 [189.15,	218.25 ,	120     ],	
 [219.22,	261.9  ,	65      ],	
 [322   ,	265.78 ,	70      ],	
 [227.95,	170.72 ,	140     ],	
 [174.6	,   236.68,	    135     ],	
 [341.44,	302.64 ,	127.5   ],	 
 [176.54,	270.63 ,	130     ],	
 [340.47,	282.27 ,	192.5   ],	 
 [334.65,	292.94 ,	202.5   ],	 
 [353   ,	275.48 ,	90      ],	
 [214.37,	209.52 ,	162.5   ],	 
 [364.72,	258    ,	140     ],	
 [376.36,	276.45 ,	165     ],	
 [206.61,	308.46 ,	195     ],	
 [338.53,	186.24 ,	120     ],	
 [183.33,	221.16 ,	155     ],	
 [350.17,	246.38 ,	102.5   ],	 
 [167.81,	233.77 ,	140     ],	
 [329.8	,   271.6  ,	95      ],	
 [358.9	,   276.45 ,	122.5   ],	 
 [325.92,	299.73 ,	145     ],	
 [196.91,	267.72 ,	130     ],	
 [231.83,	299.73 ,	182.5   ],	 
 [189.15,	219.22 ,	117.5   ],	 
 [241.53,	285.18 ,	105     ],	
 [248.32,	260.93 ,	95      ],	
 [385   ,	250.26 ,	190     ],	
 [344.35,	275.48 ,	75      ],	
 [342.41,	283.24 ,	95      ],	
 [347.26,	276.45 ,	227.5   ],	 
 [345.32,	256    ,	85      ],	
 [333.68,	264.81 ,	215     ],	
 [236.68,	245.41 ,	67.5    ] ]

# %% [markdown]
# ## DVF Files (x1,x2,x3) obtained from CLAIRE

# %% [markdown]
# ### Compose --> Normalize

# %%
# load image
#DVF_x1 = sitk.ReadImage('Data/Lung/CASE_6/displacement-field-x1.nii.gz')
#DVF_x2 = sitk.ReadImage('Data/Lung/CASE_6/displacement-field-x2.nii.gz')
#DVF_x3 = sitk.ReadImage('Data/Lung/CASE_6/displacement-field-x3.nii.gz')

DVF_x1 = sitk.ReadImage('Data/Lung/CASE_6/df_x1.nii.gz')
DVF_x2 = sitk.ReadImage('Data/Lung/CASE_6/df_x2.nii.gz')
DVF_x3 = sitk.ReadImage('Data/Lung/CASE_6/df_x3.nii.gz')

Compose = sitk.ComposeImageFilter()
Composed_DVF = Compose.Execute(DVF_x1,DVF_x2,DVF_x3)

sitk.WriteImage(Composed_DVF,'Data/Lung/CASE_6/displacement-field.nii.gz')
DVF_n_1 = sitk.ReadImage('Data/Lung/CASE_6/displacement-field.nii.gz')

print("Min & Max Pixel Values Before Normalization:")
# confirm pixel range
print('Min: %.3f, Max: %.3f' % (np.min(sitk.GetArrayFromImage(DVF_n_1)), np.max(sitk.GetArrayFromImage(DVF_n_1))))
print("#######################################################")
print("Pixel Values Before Normalization:")
print(DVF_n_1.GetPixel(0,0,0))
print(DVF_n_1.GetPixel(50,100,0))
print(DVF_n_1.GetPixel(100,0,0))

print("#######################################################")
# normalize to the range [-1, 1] -> [0, 2] -> [0, 1] -> [0, 3.14]
norm_img = sitk.Compose([(sitk.VectorIndexSelectionCast(DVF_n_1,i)+1)/2 for i in range(DVF_n_1.GetNumberOfComponentsPerPixel())])
val = 3.14
multplied_img = sitk.Compose([sitk.VectorIndexSelectionCast(norm_img,i)*val for i in range(norm_img.GetNumberOfComponentsPerPixel())])
sitk.WriteImage(multplied_img,'Data/Lung/CASE_6/displacement-field-normed_1.nii.gz')
DVF_normed_1 = sitk.ReadImage('Data/Lung/CASE_6/displacement-field-normed_1.nii.gz')

print("Min & Max Pixel Values Aafter Normalization:")
# confirm the normalization
print('Min: %.3f, Max: %.3f' % (np.min(sitk.GetArrayFromImage(DVF_normed_1)), np.max(sitk.GetArrayFromImage(DVF_normed_1))))
print("#######################################################")
print("Pixel Values After Normalization:")
print(DVF_normed_1.GetPixel(0,0,0))
print(DVF_normed_1.GetPixel(50,100,0))
print(DVF_normed_1.GetPixel(100,0,0))
# Out:
# Min & Max Pixel Values Before Normalization:
# Min: -0.452, Max: 0.084
# #######################################################
# Pixel Values Before Normalization:
# (-0.001520653022453189, -0.0029259766452014446, -0.0019357779528945684)
# (-0.003449220210313797, -0.011099576950073242, -0.003170212497934699)
# (-0.0016918836627155542, -0.00510948384180665, -0.003012059722095728)
# #######################################################
# Min & Max Pixel Values Aafter Normalization:
# Min: 0.861, Max: 1.702
# #######################################################
# Pixel Values After Normalization:
# (1.5676126050949097, 1.5654061925411225, 1.5669608253240586)
# (1.5645847535133361, 1.5525736641883852, 1.5650227981805802)
# (1.5673437517881394, 1.5619781023263932, 1.5652710640430452)

# %% [markdown]
# ### Normalize --> Compose

# %%
#DVF_x1 = sitk.ReadImage('Data/Lung/CASE_6/displacement-field-x1.nii.gz',sitk.sitkVectorFloat64)
#DVF_x2 = sitk.ReadImage('Data/Lung/CASE_6/displacement-field-x2.nii.gz',sitk.sitkVectorFloat64)
#DVF_x3 = sitk.ReadImage('Data/Lung/CASE_6/displacement-field-x3.nii.gz',sitk.sitkVectorFloat64)

#print("Min & Max Pixel Values Before Normalization for DVF_x1,  DVF_x2,  DVF_x3 :")
#print('Min: %.3f, Max: %.3f' % (np.min(sitk.GetArrayFromImage(DVF_x1)), np.max(sitk.GetArrayFromImage(DVF_x1))))
#print("---------------------------------------------")
#print('Min: %.3f, Max: %.3f' % (np.min(sitk.GetArrayFromImage(DVF_x2)), np.max(sitk.GetArrayFromImage(DVF_x2))))
#print("---------------------------------------------")
#print('Min: %.3f, Max: %.3f' % (np.min(sitk.GetArrayFromImage(DVF_x3)), np.max(sitk.GetArrayFromImage(DVF_x3))))
#print("#############################################")

#norm_img_1 = sitk.Compose([(sitk.VectorIndexSelectionCast(DVF_x1,i)+1)/2 for i in range(DVF_x1.GetNumberOfComponentsPerPixel())])
#norm_img_2 = sitk.Compose([(sitk.VectorIndexSelectionCast(DVF_x2,i)+1)/2 for i in range(DVF_x2.GetNumberOfComponentsPerPixel())])
#norm_img_3 = sitk.Compose([(sitk.VectorIndexSelectionCast(DVF_x3,i)+1)/2 for i in range(DVF_x3.GetNumberOfComponentsPerPixel())])
#val = 3.14
#multplied_img_1 = sitk.Compose([sitk.VectorIndexSelectionCast(norm_img_1,i)*val for i in range(norm_img_1.GetNumberOfComponentsPerPixel())])
#multplied_img_2 = sitk.Compose([sitk.VectorIndexSelectionCast(norm_img_2,i)*val for i in range(norm_img_2.GetNumberOfComponentsPerPixel())])
#multplied_img_3 = sitk.Compose([sitk.VectorIndexSelectionCast(norm_img_3,i)*val for i in range(norm_img_3.GetNumberOfComponentsPerPixel())])

#sitk.WriteImage(multplied_img_1,'Data/Lung/CASE_6/displacement-field-normed-x1.nii.gz')
#sitk.WriteImage(multplied_img_2,'Data/Lung/CASE_6/displacement-field-normed-x2.nii.gz')
#sitk.WriteImage(multplied_img_3,'Data/Lung/CASE_6/displacement-field-normed-x3.nii.gz')


#x1_normed = sitk.ReadImage('Data/Lung/CASE_6/displacement-field-normed-x1.nii.gz')
#x2_normed = sitk.ReadImage('Data/Lung/CASE_6/displacement-field-normed-x2.nii.gz')
#x3_normed = sitk.ReadImage('Data/Lung/CASE_6/displacement-field-normed-x3.nii.gz')

#print("Pixel Values After Normalization for x1:")
#print(x1_normed.GetPixel(0,0,0))
#print(x1_normed.GetPixel(50,100,0))
#print(x1_normed.GetPixel(100,0,0))
#print("---------------------------------------------")
#print("Pixel Values After Normalization for x2:")
#print(x2_normed.GetPixel(0,0,0))
#print(x2_normed.GetPixel(50,100,0))
#print(x2_normed.GetPixel(100,0,0))
#print("---------------------------------------------")
#print("Pixel Values After Normalization for x3:")
#print(x3_normed.GetPixel(0,0,0))
#print(x3_normed.GetPixel(50,100,0))
#print(x3_normed.GetPixel(100,0,0))
#print("#############################################")

#print("Min & Max Pixel Values After Normalization for DVF_Normed_x1, DVF_Normed_x2, DVF_Normed_x3:")
#print('Min: %.3f, Max: %.3f' % (np.min(sitk.GetArrayFromImage(x1_normed)), np.max(sitk.GetArrayFromImage(x1_normed))))
#print("---------------------------------------------")
#print('Min: %.3f, Max: %.3f' % (np.min(sitk.GetArrayFromImage(x2_normed)), np.max(sitk.GetArrayFromImage(x2_normed))))
#print("---------------------------------------------")
#print('Min: %.3f, Max: %.3f' % (np.min(sitk.GetArrayFromImage(x3_normed)), np.max(sitk.GetArrayFromImage(x3_normed))))
#print("#############################################")

#Compose = sitk.ComposeImageFilter()
#Composed_DVF_normed = Compose.Execute(x1_normed,x2_normed,x3_normed)

#sitk.WriteImage(Composed_DVF_normed,'Data/Lung/CASE_6/displacement-field-normed-2.nii.gz')
#DVF_normed_2 = sitk.ReadImage('Data/Lung/CASE_6/displacement-field-normed-2.nii.gz')

#print("Min & Max Pixel Values After Composing :")
#print('Min: %.3f, Max: %.3f' % (np.min(sitk.GetArrayFromImage(DVF_normed_2)), np.max(sitk.GetArrayFromImage(DVF_normed_2))))
#print("#############################################")
#print(DVF_normed_2.GetPixel(0,0,0))
#print(DVF_normed_2.GetPixel(50,100,0))
#print(DVF_normed_2.GetPixel(100,0,0))

# %% [markdown]
# #### Check Nibabel package

# %%
#pip install nibabel

# %%
#import nibabel as nib

# %%
#img = nib.load('Data/Lung/CASE_6/displacement-field-x1.nii.gz')
#img.shape
#header = img.header
#print(header)            
#print(header.get_data_dtype())
#img.affine
#img.shape

#img = sitk.ReadImage('Data/Lung/CASE_6/displacement-field-x1.nii.gz')
#print(img.GetPixel(0,0,0))

# %%
#img = nib.load('Data/Lung/CASE_6/displacement-field.nii.gz')
#img.shape

# %%
#help(FileImage.GetPixel)

# %%
#from numpy import asarray
# load image
#FileImage = sitk.ReadImage('Data/Lung/CASE_6/displacement-field.nii.gz')
#pixels = np.asarray(FileImage)
#pixels.shape
# confirm pixel range
#print('Data Type: %s' % pixels.dtype)
#print('Min: %.3f, Max: %.3f' % (pixels.min(), pixels.max()))
# normalize to the range 0-π
#pixels *= 3.14
# confirm the normalization
#print('Min: %.3f, Max: %.3f' % (pixels.min(), pixels.max()))

# %% [markdown]
# # 2. Displacement field transform created from the displacement-image:

# %%
transform = sitk.DisplacementFieldTransform(sitk.ReadImage('Data/Lung/CASE_6/displacement-field-normed_1.nii.gz', sitk.sitkVectorFloat64))

# %% [markdown]
# # 3. Compute Target Registration Error:

# %%
from registration_utilities import registration_errors
from gui import display_errors

# %% [markdown]
#    ### TRE Before IR:

# %%
pre_errors_mean, pre_errors_std, pre_errors_min, pre_errors_max, _ = registration_errors(sitk.Transform(), reference_fixed_point_list_T00, reference_moving_point_list_T50, display_errors = True)
print('Before registration, errors (TRE) in millimeters, mean(std): {:.2f}({:.2f}), max: {:.2f}'.format(pre_errors_mean, pre_errors_std, pre_errors_max))
# Out:
# Before registration, errors (TRE) in millimeters, mean(std): 10.89(6.96), max: 27.59

# %% [markdown]
# ### TRE After IR:

# %%
post_errors_mean, post_errors_std, post_errors_min, post_errors_max, _ = registration_errors(transform, reference_fixed_point_list_T00, reference_moving_point_list_T50, display_errors = True)
print('After registration, errors (TRE) in millimeters, mean(std): {:.2f}({:.2f}), max: {:.2f}'.format(post_errors_mean, post_errors_std, post_errors_max))
# Out:
# After registration, errors (TRE) in millimeters, mean(std): 12.14(6.94), max: 28.16

# %%
#%matplotlib inline
#import matplotlib.pyplot as plt

# %%
#initial_TRE = registration_errors(sitk.Transform(), reference_fixed_point_list_T00, reference_moving_point_list_T50)
#final_TRE = registration_errors(transform, reference_fixed_point_list_T00, reference_moving_point_list_T50)


#plt.hist(initial_TRE, bins=10, alpha=0.5, label='before registration')
#plt.hist(final_TRE, bins=20, alpha=0.5, label='after registration')
#plt.legend()
#plt.title('TRE histogram');
